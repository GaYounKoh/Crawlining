# %% [markdown]
# # Library Load

# %%
from glob import glob
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import os

import time
from tqdm import tqdm

main_path = 'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/'

# %% [markdown]
# # glob test

# %%
# path = main_path + '1 00 에볼라바이러스병'
# path
# file_list = glob(path+'/'+'*')
# file_list

# %%
# new = []
# for enu, i in enumerate(file_list):
#     pick = i.split(' ')[-1].split('.')[:-1]
# #     pick
    
#     tmp_filenm = ' '.join(i.split(' ')[:-1])

#     if pick[0][0] == '(': # 괄호로 시작하면 그 사이 값만 꺼내 주세요.
#         if len(pick[0][1:-1]) <= 3:
# #             len(pick[0][1:-1])
#             new_pick = f"{'0'*(3-len(pick[0][1:-1]))}{pick[0][1:-1]}"
# #             new_pick
#             new.append(f"{tmp_filenm} ({new_pick}).csv")
#         else:
#             new.append(f"{tmp_filenm} ({enu}).csv")
    
# #     if pick[0][1] == '2':
# #         break

# %% [markdown]
# # rename

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\바탕 화면\\다운로드'

# %%
# for i in range(len(file_list)):
#     ## file_list의 i번째를 new의 i번째로 rename
#     os.rename(file_list[i], os.path.join(path, new[i])) # rename의 뒤에는 꼭 path를 포함한 file의 이름이 (즉, 경로) 와야 함.

# %% [markdown]
# # labeling을 위한 작업

# %% [markdown]
# ## 시도lst

# %%
시도lst = ['서울', '부산', '대구', '인천',
      '광주', '대전', '울산', '경기', '강원', 
      '충북', '충남', '전북', '전남', '경북',
      '경남', '제주', '세종']
len(시도lst) # 17
# Out:
# 17

# %% [markdown]
# ## name2병id (len 63)

# %%
급1병_lst = ['에볼라바이러스병', '마버그열', '라싸열', '크리미안콩고출혈열', '남아메리카출혈열', '리프트밸리열', '두창', '페스트',
            '탄저', '보툴리눔독소증', '야토병', '중증급성호흡기증후군(SARS)', '중동호흡기증후군(MERS)', '동물인플루엔자 인체감염증',
            '신종인플루엔자', '디프테리아']

급2병_lst = ['수두', '홍역', '콜레라', '장티푸스', '파라티푸스', '세균성이질', '장출혈성대장균감염증', 'A형간염', '백일해',
            '유행성이하선염', '풍진(2018년이전)', '풍진(선천성)', '풍진(후천성)', '폴리오', '수막구균 감염증',
            'b형헤모필루스인플루엔자', '폐렴구균 감염증', '한센병', '성홍열', '반코마이신내성황색포도알균(VRSA) 감염증',
            '카바페넴내성장내세균속균종(CRE) 감염증', 'E형간염']

급3병_lst = ['파상풍', 'B형간염', '일본뇌염', 'C형간염', '말라리아', '레지오넬라증', '비브리오패혈증', '발진티푸스', '발진열',
             '쯔쯔가무시증', '렙토스피라증', '브루셀라증', '공수병', '신증후군출혈열',
             '크로이츠펠트-야콥병(CDJ) 및 변종크로이츠펠트-야콥병(vCJD)', '황열', '뎅기열', '큐열', '웨스트나일열', '라임병',
             '진드기매개뇌염', '유비저', '치쿤구니야열', '중증열성혈소판감소증후군(SFTS)', '지카바이러스감염증']

병name_lst = 급1병_lst + 급2병_lst + 급3병_lst
len(병name_lst)
# Out:
# 63

# %%
병id_lst = [i for i in range(len(급1병_lst))] + [i for i in range(len(급2병_lst))] + [i for i in range(len(급3병_lst))]

name2병id = {병name_lst[i] : 병id_lst[i] for i in range(len(병id_lst))}
len(name2병id)
# Out:
# 63

# %%
급id_match_lst = [1]*len(급1병_lst) + [2]*len(급2병_lst) + [3]*len(급3병_lst)

# %% [markdown]
# ## 지역 (len 272)

# %%
군구서울 = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구',
           '종로구', '중구', '중랑구']

군구부산 = ['강서구', '금정구', '기장군', '남구', '동구', '동래구', '부산진구', '북구', '사상구', '사하구', '서구', '수영구', '연제구', '영도구', '중구', '해운대구']

군구대구 = ['남구', '달서구', '달성군', '동구', '북구', '서구', '수성구', '중구']

군구인천 = ['강화군', '계양구', '미추홀구', '남동구', '동구', '부평구', '서구', '연수구', '옹진군', '중구']

군구광주 = ['광산구', '남구', '동구', '북구', '서구']

군구대전 = ['대덕구', '동구', '서구', '유성구', '중구']

군구울산 = ['남구', '동구', '북구', '울주군', '중구']

군구경기 = ['가평군', '고양시 덕양구', '고양시 일산동구', '고양시 일산서구', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시', '부천시 소사구', '부천시 오정구', '부천시 원미구', '성남시 분당구', '성남시 수정구',
           '성남시 중원구', '수원시 권선구', '수원시 영통구', '수원시 장안구', '수원시 팔달구', '시흥시', '안산시 단원구', '안산시 상록구', '안성시', '안양시 동안구', '안양시 만안구', '양주시', '양평군', '여주시', '연천군', '오산시', '용인시 기흥구', '용인시 수지구',
           '용인시 처인구', '의왕시', '의정부시', '이천시', '파주시', '평택시', '포천시', '하남시', '화성시', '양주군', '고양시 일산구', '포천군', '용인시', '남양주', '고양시 일산동', '안산시', '부천시']

군구강원 = ['강릉시', '고성군', '동해시', '삼척시', '속초시', '양구군', '양양군', '영월군', '원주시', '인제군', '정선군', '철원군', '춘천시', '태백시', '평창군', '홍천군', '화천군', '횡성군']

군구충북 = ['괴산군', '단양군', '보은군', '영동군', '옥천군', '음성군', '제천시',' 증평군', '진천군', '청원군', '(구)청주시 상당구', '(구)청주시 흥덕구', '충주시', '청주시 상당구', '청주시 흥덕구', '청주시 서원구', '청주시 청원구']

군구충남 = ['계룡시', '공주시', '금산군', '논산시', '당진시', '보령시', '부여군', '서산시', '서천군', '아산시', '연기군', '예산군', '천안시', '청양군', '태안군', '홍성군', '천안시 동남구', '천안시 서북구']

군구전북 = ['고창군', '군산시' ,'김제시', '남원시', '무주군', '부안군', '순창군', '완주군', '익산시', '임실군', '장수군', '전주시 덕진구', '전주시 완산구', '정읍시', '진안군', '전주시']

군구전남 = ['강진군', '고흥군', '곡성군', '광양시', '구례군', '나주시', '담양군', '목포시', '무안군', '보성군', '순천시', '신안군', '여수시', '영광군', '영암군', '완도군', '장성군', '장흥군', '진도군', '함평군', '해남군', '화순군']

군구경북 = ['경산시', '경주시', '고령군', '구미시', '군위군', '김천시', '문경시', '봉화군', '상주시', '성주군', '안동시', '영덕군', '영양군', '영주시', '영천시', '예천군', '울릉군', '울진군', '의성군', '청도군', '청송군', '칠곡군',
           '포항시 남구', '포항시 북구', '포항시']

군구경남 = ['거제시', '거창군', '고성군', '김해시', '남해군', '마산시', '밀양시', '사천시', '산청군', '양산시', '의령군', '진주시', '진해시', '창녕군', '창원시', '통영시', '하동군', '함안군', '함양군', '합천군', '창원시 마산합포구', '창원시 마산회원구',
           '창원시 성산구', '창원시 의창구', '창원시 진해구']

군구제주 = ['서귀포시', '제주시', '남제주군', '북제주군']

군구세종 = ['세종시']

# %% [markdown]
# ### 각 시도별 군구 길이

# %%
for i in 시도lst:
    i, len(globals()[f'군구{i}'])
# Out:
# ('서울', 25)
# ('부산', 16)
# ('대구', 8)
# ('인천', 10)
# ('광주', 5)
# ('대전', 5)
# ('울산', 5)
# ('경기', 52)
# ('강원', 18)
# ('충북', 17)
# ('충남', 18)
# ('전북', 16)
# ('전남', 22)
# ('경북', 25)
# ('경남', 25)
# ('제주', 4)
# ('세종', 1)

# %% [markdown]
# ### 모든 시도의 모든 군구의 수

# %%
군구all = 군구서울 + 군구부산 + 군구대구 + 군구인천 + 군구광주 + 군구대전 + 군구울산 + 군구경기 + 군구강원 + 군구충북 + 군구충남 + 군구전북 + 군구전남 + 군구경북 + 군구경남 + 군구제주 + 군구세종
len(군구all)
# Out:
# 272

# %% [markdown]
# # rename 한 번에 실행

# %%
for enu, i in tqdm(enumerate(병name_lst)):
    
    if i == '에볼라바이러스병': # test로 먼저 진행해서 얘는 빼고 진행.
        continue
    
    if len(str(name2병id[i])) == 1:
        path = f'{main_path}{급id_match_lst[enu]} 0{name2병id[i]} {i}'
    elif len(str(name2병id[i])) == 2:
        path = f'{main_path}{급id_match_lst[enu]} {name2병id[i]} {i}'
    
    file_list = glob(path+'/'+'*')
    
    ## new
    new = [] # 매 병마다 갱신할 new
    for enu, j in enumerate(file_list):
        pick = j.split(' ')[-1].split('.')[:-1]
        tmp_filenm = ' '.join(j.split(' ')[:-1])

        if pick[0][0] == '(': # 괄호로 시작하면 그 사이 값만 꺼내 주세요.
            if len(pick[0][1:-1]) <= 3:
                new_pick = f"{'0'*(3-len(pick[0][1:-1]))}{pick[0][1:-1]}"
                new.append(f"{tmp_filenm} ({new_pick}).csv")
            else:
                new.append(f"{tmp_filenm} ({enu}).csv")
    
    
    ## rename
    for k in range(len(file_list)):
        ## file_list의 k번째를 new의 k번째로 rename
        os.rename(file_list[k], os.path.join(path, new[k])) # rename의 뒤에는 꼭 path를 포함한 file의 이름이 (즉, 경로) 와야 함.
    
    time.sleep(1)
# Out:
# 63it [01:08,  1.09s/it]

# %%
sorted(new)
# Out:
# ['C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (001).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (002).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (003).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (004).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (005).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (006).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (007).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (008).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (009).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (010).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (011).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (012).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (013).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (014).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (015).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (016).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (017).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (018).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (019).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (020).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (021).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (022).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (023).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (024).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (025).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (026).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (027).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (028).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (029).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (030).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (031).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (032).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (033).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (034).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (035).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (036).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (037).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (038).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (039).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (040).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (041).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (042).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (043).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (044).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (045).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (046).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (047).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (048).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (049).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (050).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (051).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (052).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (053).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (054).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (055).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (056).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (057).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (058).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (059).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (060).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (061).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (062).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (063).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (064).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (065).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (066).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (067).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (068).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (069).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (070).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (071).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (072).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (073).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (074).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (075).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (076).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (077).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (078).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (079).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (080).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (081).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (082).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (083).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (084).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (085).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (086).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (087).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (088).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (089).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (090).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (091).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (092).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (093).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (094).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (095).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (096).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (097).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (098).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (099).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (100).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (101).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (102).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (103).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (104).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (105).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (106).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (107).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (108).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (109).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (110).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (111).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (112).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (113).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (114).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (115).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (116).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (117).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (118).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (119).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (120).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (121).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (122).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (123).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (124).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (125).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (126).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (127).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (128).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (129).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (130).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (131).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (132).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (133).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (134).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (135).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (136).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (137).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (138).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (139).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (140).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (141).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (142).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (143).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (144).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (145).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (146).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (147).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (148).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (149).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (150).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (151).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (152).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (153).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (154).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (155).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (156).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (157).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (158).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (159).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (160).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (161).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (162).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (163).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (164).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (165).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (166).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (167).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (168).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (169).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (170).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (171).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (172).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (173).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (174).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (175).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (176).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (177).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (178).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (179).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (180).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (181).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (182).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (183).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (184).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (185).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (186).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (187).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (188).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (189).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (190).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (191).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (192).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (193).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (194).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (195).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (196).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (197).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (198).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (199).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (200).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (201).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (202).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (203).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (204).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (205).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (206).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (207).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (208).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (209).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (210).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (211).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (212).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (213).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (214).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (215).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (216).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (217).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (218).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (219).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (220).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (221).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (222).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (223).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (224).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (225).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (226).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (227).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (228).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (229).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (230).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (231).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (232).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (233).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (234).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (235).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (236).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (237).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (238).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (239).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (240).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (241).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (242).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (243).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (244).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (245).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (246).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (247).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (248).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (249).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (250).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (251).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (252).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (253).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (254).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (255).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (256).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (257).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (258).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (259).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (260).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (261).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (262).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (263).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (264).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (265).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (266).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (267).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (268).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (269).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (270).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (271).csv',
#  'C:/Users/Admin/바탕 화면/다운로드/정형철교수님/지역별_질병별_연도별_성별_연령별_발생/1 01 마버그열\\기본통계_성별_연령별_마버그열 (272).csv']
